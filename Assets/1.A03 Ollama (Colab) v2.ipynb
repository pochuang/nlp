# %%
# 安裝 Ollama
# !apt-get install -y lshw pciutils
# !apt-get install zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# 背景啟動服務
import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids usb.ids
# The following NEW packages will be installed:
#   libpci3 lshw pci.ids pciutils usb.ids
# 0 upgraded, 5 newly installed, 0 to remove and 100 not upgraded.
# Need to get 884 kB of archives.
# After this operation, 3,256 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Fetched 884 kB in 0s (7,814 kB/s)
# Selecting previously unselected package pci.ids.
# (Reading database ... 122402 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package lshw.
# Preparing to unpack .../lshw_02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1_amd64.deb ...
# Unpacking lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Selecting previously unselected package usb.ids.
# Preparing to unpack .../usb.ids_2022.04.02-1_all.deb ...
# Unpacking usb.ids (2022.04.02-1) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up lshw (02.19.git.2021.06.19.996aaad9c7-2ubuntu0.22.04.1) ...
# Setting up usb.ids (2022.04.02-1) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up pciutils (1:3.7.0-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 100 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (10.4 MB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 122435 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# <Popen: returncode: None args: ['ollama', 'serve']>

# %%
# 下載模型
# ollama pull gemma4:e2b

# model_name = "gemma3:4b"
model_name = "gemma4:e2b"

import subprocess
from IPython.display import clear_output
import sys

process = subprocess.Popen(
    ["ollama", "pull", model_name],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True
)

last_line = ""
for chunk in process.stdout:
    # 按 \r 分割，只取最後一段（最新狀態）
    parts = chunk.split('\r')
    last_part = parts[-1].strip()
    if last_part:
        last_line = last_part
        clear_output(wait=True)
        print(last_line, flush=True)

process.wait()
print("✅ 下載完成")
# Out:
# success
# ✅ 下載完成

# %%
# 測試連線
! curl http://127.0.0.1:11434/
# Out:
# Ollama is running

# %% [markdown]
# # 測試

# %%
! pip install langchain_ollama
# Out:
# Collecting langchain_ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in /usr/local/lib/python3.12/dist-packages (from langchain_ollama) (1.3.1)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain_ollama)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.7.34)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.14.1)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama<1.0.0,>=0.6.1->langchain_ollama) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.1->langchain_ollama) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.1->langchain_ollama) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.1->langchain_ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.1->langchain_ollama) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.6.1->langchain_ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.5.0)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama, langchain_ollama
# Successfully installed langchain_ollama-1.1.0 ollama-0.6.2

# %%
# Ollama 本機端
import os
from langchain_ollama import ChatOllama

# model_name = 'gemma4:e2b'
llm = ChatOllama(model=model_name, base_url="http://localhost:11434")

for chunk in llm.stream("機器學習的原理"):
    print(chunk.content, end='')
# Out:
# 機器學習（Machine Learning, ML）是人工智慧（AI）的一個重要分支，它讓電腦能夠從數據中學習模式、識別趨勢並做出預測或決策，而**無需被明確地編程**。
#
# 要理解機器學習的原理，我們需要從以下幾個核心概念和流程入手。
#
# ---
#
# ## 一、 機器學習的基礎流程 (The ML Pipeline)
#
# 無論是哪種機器學習，其核心流程都遵循相似的步驟：
#
# 1. **數據收集 (Data Collection):** 這是所有學習的基礎。你需要大量的、相關的數據（Data）。
# 2. **數據預處理 (Data Preprocessing):** 原始數據通常是雜亂的、有缺失值的或格式不一致的。需要進行清洗、轉換、正規化（Normalization）等步驟，使數據適合演算法的輸入。
# 3. **特徵工程 (Feature Engineering):** 從原始數據中提取出對模型有意義的、能反映潛在模式的特徵（Features）。這是決定模型表現的關鍵步驟。
# 4. **模型選擇 (Model Selection):** 根據問題類型（分類、迴歸、聚類等），選擇合適的機器學習演算法（如線性迴歸、決策樹、神經網絡等）。
# 5. **模型訓練 (Model Training):** 將預處理後的數據輸入給選擇的演算法進行學習，讓模型從中提取出規律。
# 6. **模型評估 (Model Evaluation):** 使用獨立的測試數據來評估模型的準確性和泛化能力，確保模型不是僅僅「記住」訓練數據，而是能夠對新數據做出準確的預測。
# 7. **模型部署 (Deployment):** 將訓練好的模型應用到實際問題中。
#
# ---
#
# ## 二、 機器學習的三大主要類型 (The Three Main Paradigms)
#
# 根據數據的類型和學習的方式，機器學習主要分為三種：
#
# ### 1. 教學式學習 (Supervised Learning)
#
# * **原理：** 模型在訓練時會獲得「標籤」（Labels）。輸入數據（$X$）和對應的輸出結果（$Y$）成對存在。模型需要學習如何將 $X$ 映射到正確的 $Y$。
# * **目標：** 預測。
# * **應用：**
#     * **分類 (Classification)：** 預測一個類別標籤（例如：垃圾郵件/非垃圾郵件，貓/狗）。
#     * **迴歸 (Regression)：** 預測一個連續的數值（例如：房價、溫度、身高）。
# * **關鍵概念：** 訓練集（Training Set）、標籤（Labels）、誤差（Error）。
#
# ### 2. 非監督式學習 (Unsupervised Learning)
#
# * **原理：** 模型在訓練時**不**有任何標籤。模型必須自己從數據中尋找隱藏的結構、模式和群組關係。
# * **目標：** 探索和發現結構。
# * **應用：**
#     * **聚類 (Clustering)：** 將相似的數據點分組（例如：市場區隔、顧客分群）。
#     * **降維 (Dimensionality Reduction)：** 減少數據的特徵數量，同時保留大部分信息。
# * **關鍵概念：** 群組（Clusters）、距離（Distance）、相似性（Similarity）。
#
# ### 3. 強化學習 (Reinforcement Learning, RL)
#
# * **原理：** 模型（Agent）在一個環境中進行互動，通過不斷的嘗試和錯誤，學習如何做出最佳的決策以最大化累積的獎勵（Reward）。
# * **目標：** 決策。
# * **應用：** 自動駕駛、遊戲AI（如AlphaGo）、機器人控制。
# * **關鍵概念：** 智能體（Agent）、環境（Environment）、獎勵機制（Reward）、策略（Policy）。
#
# ---
#
# ## 三、 模型學習的數學原理：如何讓模型「學習」？
#
# 機器學習的運算核心是**數學**。模型學習的過程，本質上就是一個**優化**（Optimization）的過程。
#
# ### 1. 成本函數/損失函數 (Loss Function / Cost Function)
#
# 這是衡量模型預測結果與實際結果之間差異的數學指標。
#
# * **作用：** 量化模型當前的「錯誤」或「不確定性」。
# * **目標：** 最小化這個損失函數的值。
# * **範例：**
#     * **均方誤差 (MSE)：** 常用於迴歸問題，計算預測值與真實值之間的平方差的平均值。
#     * **交叉熵 (Cross-Entropy)：** 常用於分類問題，衡量機率分配的差異。
#
# ### 2. 優化算法：梯度下降 (Gradient Descent)
#
# 梯度下降是機器學習中最核心的優化算法，它告訴模型如何調整其參數（Weights and Biases）來最小化成本函數。
#
# * **核心思想：** 想像你在一個崎嶇的山上（成本函數的最低點），你想要找到最低點。梯度下降就是不斷朝著坡度最陡峭（梯度最大）的方向往下走，這樣就能最快地到達谷底。
# * **過程：**
#     1. 計算當前參數的**梯度**（即誤差對每個參數的偏導數）。
#     2. 根據梯度和一個學習率（Learning Rate），調整參數的方向和大小。
#     3. 重複這個過程，直到損失函數達到最小值。
#
# ### 3. 參數與權重 (Parameters and Weights)
#
# * **參數 (Parameters)：** 模型需要學習調整的變數。例如，在線性迴歸中，這些參數就是斜率（Weight）和截距（Bias）。
# * **權重 (Weights)：** 在神經網絡中，這些是連接不同神經元的強度。模型通過訓練來調整這些權重，從而定義數據之間的關係。
#
# ---
#
# ## 總結：機器學習的精髓
#
# 機器學習的原理可以總結為：
#
# > **通過數學優化（如梯度下降），讓一個模型從大量的數據中學習潛在的數學關係，以便在面對未見過的新數據時，能夠做出準確的預測或決策。**
