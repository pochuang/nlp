# %% [markdown]
# # 網路搜尋
# 請實作出一個可以進行網路搜尋的工具

# %%
! pip install ddgs

# %%
from ddgs import DDGS

results = DDGS().text("python programming", max_results=5)
print(results)
# Out:
# [{'title': 'Python (programming language)', 'href': 'https://en.wikipedia.org/wiki/Python_(programming_language)', 'body': 'Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation, "plain English" naming, an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5, capabilities and keywords for typing were added to the language, allowing optional static typing. As of 2026, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the project\'s annual release cycle an
# ...

# %%
from ddgs import DDGS

results = DDGS().text("機器學習", max_results=5)
print(results)
# Out:
# [{'title': '機器學習 - 維基百科，自由的百科全書', 'href': 'https://zh.wikipedia.org/zh-tw/机器学习', 'body': '機器學習有下面幾種定義： 機器學習是一門人工智慧的科學，該領域的主要研究對象是人工智慧，特別是如何在經驗學習中改善具體演算法的效能。 機器學習是對能通過經驗自動改進的計算機演算法的研究。 機器學習是用數據或以往的經驗，以此優化計算機程式的效能標準。 另外，電腦科學家 ...'}, {'title': '機器學習是什麼？3分鐘學會Machine Learning的原理及各種類型', 'href': 'https://kuyijourney.com/article/ai/basics/what-is-machines-learning/', 'body': '機器學習 (Machine Learning) 是什麼？三種學習方式與運作原理 機器學習 (ML) 是實現人工智慧的一種「方法」。但具體來說，機器到底是怎麼「學習」的？它會像人類一樣看書背單字嗎？ 簡單來說，傳統的電腦程式是我們教它「做什麼」（寫死規則）；而機器學習則是我們給它數據，讓它自己學會 ...'}, {'title': '機器學習是什麼？Ai機器學習定義、演算法類型、應用情境一次看-asu在线官网', 'href': 'https://cn.asu.edu/machine-learning/', 'body': '機器學習是什麼？AI機器學習應用在哪裡？本文將帶你認識機器學習定義、優勢與運作流程，並解析AI機器學習演算法類型，以及與深度學習的差異，最後再為你統整機器學習模型的學習資源與應用情境!'}, {'title': '機器學習定義？與深度學習有6差異!4類型入門＋6商業應用介紹 - ADBest：不只流量，我們更在乎留量', 'href': 'https://adbest.com.tw/blog/what-is-machine-learning/', 'body': '機器學習是什麼？我們先拆解機器學習與深度學習6個差異，並解析機器學習運作7步驟，也會帶你認識機器學習4種類型與應用情境。最後觀察6種產業案例、10個QA解答疑惑，讓我們一步步掀開機器學習的面紗吧!'}, {'title': '什麼是機器學習？ | Mac
# ...
