# %% [markdown]
# # Ollama雲端模型
# 1. 到Ollama官網註冊帳號
# https://ollama.com/
#
# 2. 產生API Key
# https://ollama.com/settings/keys
#
# 3. 剩下的使用額度
# https://ollama.com/settings
#
# 4. 付費升級
# https://ollama.com/settings/billing

# %%
import os
from langchain_ollama import ChatOllama

# 1. 前往 ollama.com 取得 API Key 並設定環境變數
os.environ["OLLAMA_API_KEY"] = "36347a175a124f9db2ba64a163ab9a7f.NNMlDtjf4oENh5hIEoehEZKT"

# 2. 初始化模型，將 base_url 指向官方雲端網址
llm = ChatOllama(
    model="gemma4:31b-cloud",  # 指定雲端模型名稱
    base_url="https://ollama.com",
    temperature=0.7
)

# 3. 呼叫模型
response = llm.invoke("機器學習的定義")
print(response.content)
# Out:
# **機器學習（Machine Learning, ML）** 是人工智慧（Artificial Intelligence, AI）的一個子領域。簡單來說，它的核心定義是：**讓電腦在不經過「明確編程」的情況下，能夠從數據中學習並找出規律，從而對新數據做出預測或決策的能力。**
#
# 為了讓你更透徹地理解，我們可以從以下三個維度來拆解：
#
# ### 1. 傳統編程 vs. 機器學習
# *   **傳統編程（Traditional Programming）：**
#     *   **邏輯：** 數據 $\rightarrow$ **規則（由人類寫死）** $\rightarrow$ 結果。
#     *   *例子：* 如果你想讓電腦辨識垃圾郵件，你必須寫死規則：「如果郵件包含『中獎』且包含『點擊連結』，則判定為垃圾郵件」。如果垃圾郵件變種了，你就得手動修改規則。
# *   **機器學習（Machine Learning）：**
#     *   **邏輯：** 數據 $\rightarrow$ **結果（標籤）** $\rightarrow$ **規則（由機器自動學習）**。
#     *   *例子：* 你給電腦 1 萬封郵件，告訴它哪些是垃圾郵件，哪些不是。電腦會自動分析這些郵件的特徵（字詞分佈、發信人等），自己推導出一套判別規則。
#
# ---
#
# ### 2. 機器學習是如何運作的？
# 機器學習的過程通常包含以下步驟：
# 1.  **數據收集：** 獲取大量的樣本（例如：成千上萬張貓狗的照片）。
# 2.  **特徵提取：** 找出影響結果的關鍵因素（例如：耳朵形狀、眼睛顏色）。
# 3.  **訓練模型：** 使用演算法（Algorithm）在數據中尋找數學模式，建立一個「模型」。
# 4.  **預測/推論：** 將新數據輸入模型，由模型給出答案（例如：這張新照片 95% 的機率是貓）。
#
# ---
#
# ### 3. 常見的三大類學習方式
# 根據數據的性質，機器學習主要分為三類：
#
# *   **監督式學習 (Supervised Learning)：**
#     *   **特點：** 數據有「標籤」（答案）。
#     *   **目標：** 預測未來。
# ...

# %% [markdown]
# # Ollama 本地端模型

# %%
import os
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma3:1b",  # 指定雲端模型名稱
    base_url="http://localhost:11434",
    temperature=0.7
)

# 3. 呼叫模型
response = llm.invoke("機器學習的定義")
print(response.content)
# Out:
# 機器學習 (Machine Learning, ML) 是一個廣泛的概念，但簡單來說，它指的是**讓電腦能夠像人類一樣學習和從數據中獲得知識，並利用這些知識來進行預測或做出決策，而無需明確地編寫出所有的規則**。
#
# 以下是機器學習更詳細的定義，包含幾個關鍵方面：
#
# **1. 核心概念：**
#
# * **學習 (Learning):** 機器學習的核心是讓電腦從數據中學習，而不是由人工編寫的規則。
# * **數據 (Data):** 機器學習系統需要大量數據來訓練和提升其能力。
# * **算法 (Algorithms):**  機器學習系統使用特定的算法來分析數據並找到模式。
# * **預測 (Prediction):**  機器學習系統利用學到的模式來預測新的數據。
#
# **2. 機器學習的類型：**
#
# 機器學習可以分為不同的類型，主要根據學習方式來分類：
#
# * **教師型學習 (Supervised Learning):**  教師型學習系統需要人工提供標記數據，讓系統學習如何將輸入數據映射到輸出數據。 比如，訓練一個圖像識別系統，需要提供大量的圖片，告訴它圖片的標籤 (例如，"貓"、"狗" 等)。
# * **非教師型學習 (Unsupervised Learning):** 這種學習方式沒有人工標記數據，讓系統自己去探索數據中的模式和結構。 比如，客戶分群，從客戶數據中找出不同類型的客戶，並針對不同群體制定不同的策略。
# * **半教師型學習 (Semi-Supervised Learning):** 結合了教師型和非教師型學習。 數據中既有標記數據，也有未標記數據。
# * **強學習型學習 (Reinforcement Learning):**  這種學習方式通過與環境互動來獲得獎勵，讓系統學習如何進行最佳行為，最終獲得獎勵，並不斷調整策略。 比如，機器人學習如何在複雜的環境中移動。
#
# **3. 機器學習的關鍵技術：**
#
# * **線性回歸 (Linear Regression):**  建立線性的關係，預測一個變量的值。
# * **支持向量機 (Support Vector Machines, SVM):**  找到最佳的數據劃分線。
# ...
