# %% [markdown]
# Lab 1-1. 示範如何使用 ollama

# %% [markdown]
# 1. 到 https://ollama.com 註冊帳號
# 2. 在 https://ollama.com/settings/keys 申請 API KEY

# %%
# !pip install langchain_ollama

# %%
import os
from langchain_ollama import ChatOllama

if "OLLAMA_API_KEY" not in os.environ:
    os.environ["OLLAMA_API_KEY"] = "9018e404b4ed45acb78520e2a9520840.FncnM1F6Mudh1wPhZKMH3fjw"    

model_name = 'gemma4:31b-cloud'

llm = ChatOllama(model=model_name, base_url="https://ollama.com")

# 1. Output the response of the model
response = llm.invoke("請告訴我學習機器學習數學的資源")
print(response.content)

# 2. Stream the response of the model
# for chunk in llm.stream("請告訴我學習機器學習數學的資源"):
#     print(chunk.content, end='')
# Out:
# 學習機器學習（ML）的數學，最重要的是**不要試圖在開始寫程式前就把所有數學書看完**。最好的方法是「**由淺入深，同步並進**」：先學習基礎概念 $\rightarrow$ 實作程式 $\rightarrow$ 遇到不懂的數學再深入鑽研。
#
# 機器學習的核心數學主要分為四大塊：**線性代數、微積分、機率與統計、以及優化理論**。以下是根據不同學習階段推薦的資源：
#
# ---
#
# ### 第一階段：快速入門（直觀理解 $\rightarrow$ 概念）
# 如果你不想先啃厚書，想快速知道數學在 ML 裡怎麼用，推薦這些資源：
#
# 1.  **3Blue1Brown (YouTube 頻道)** $\leftarrow$ **最強烈推薦**
#     *   **線性代數本質 (Essence of Linear Algebra)**：讓你「視覺化」矩陣和向量，而不是死背公式。
#     *   **微積分本質 (Essence of Calculus)**：理解導數和積分的真正意義。
#     *   **神經網絡 (Neural Networks)**：解釋反向傳播（Backpropagation）的數學邏輯。
# 2.  **StatQuest with Josh Starmer (YouTube 頻道)**
#     *   將複雜的統計學和 ML 算法（如 SVM, Random Forest, PCA）用極其簡單的方式拆解，非常適合初學者。
#
# ---
#
# ### 第二階段：系統化學習（基礎理論 $\rightarrow$ 知識體系）
# 當你需要建立紮實的基礎時，可以參考以下課程或書籍：
#
# #### 1. 線性代數 (Linear Algebra)
# *   **MIT 18.06 Gilbert Strang 教授課程**：全球最經典的線性代數課（可在 YouTube 或 MIT OCW 找到）。
# *   **書籍：$\textit{Introduction to Linear Algebra}$ (Gilbert Strang)**。
#
# #### 2. 微積分 (Calculus)
# *   **Khan Academy (可汗學院)**：適合從零開始補習，互動性強，範圍涵蓋單變量與多變量微積分。
# *   **重點學習內容**：偏導數 (Partial Derivatives)、梯度 (Gradient)、連鎖律 (Chain Rule)。
#
# #### 3. 機率與統計 (Probability & Statistics)
# *   **Coursera: $\textit{Probability and Statistics}$ 系列課程**。
# *   **書籍：$\textit{Introduction to Probability}$ (Bertsekas & Tsitsiklis)**。
# *   **重點學習內容**：條件機率、貝葉斯定理 (Bayes' Theorem)、期望值、正態分佈 (Gaussian Distribution)。
#
# ---
#
# ### 第三階段：ML 專屬數學（理論 $\rightarrow$ 演算法）
# 這類資源直接將數學應用在機器學習模型中：
#
# 1.  **Mathematics for Machine Learning (MML)**
#     *   **網站/書籍：[mml-book.com](https://mml-book.com/)**
#     *   這本是目前最推薦的「一站式」數學指南。它將線性代數、微積分、機率全部整合，並直接告訴你這些數學如何應用在 PCA、回歸和支持向量機中。
# 2.  **Deep Learning Book (Ian Goodfellow)**
#     *   **網站：[deeplearningbook.org](https://www.deeplearningbook.org/)**
#     *   第一部分（Applied Math）詳細介紹了深度學習所需的數學背景。
#
# ---
#
# ### 學習路徑建議 (Learning Roadmap)
#
# 如果你感到迷茫，可以按照這個順序：
#
# 1.  **視覺化啟蒙** $\rightarrow$ 觀看 3Blue1Brown 的線性代數系列。
# 2.  **實作入門** $\rightarrow$ 學習 Python $\rightarrow$ 使用 Scikit-learn 跑簡單模型（如線性回歸）。
# 3.  **數學回溯** $\rightarrow$ 當你問「為什麼權重要用梯度下降更新？」 $\rightarrow$ 去看微積分的**梯度 (Gradient)** $\rightarrow$ 回到 MML 書籍。
# 4.  **深入研究** $\rightarrow$ 學習機率論 $\rightarrow$ 理解生成模型 (VAE, GAN) 或貝葉斯網絡。
#
# ### 總結資源對照表
#
# | 數學領域 | 直觀理解 (輕量) | 系統學習 (中量) | 專業深挖 (重量) |
# | :--- | :--- | :--- | :--- |
# | **線性代數** | 3Blue1Brown | Khan Academy | MIT 18.06 (Strang) |
# | **微積分** | 3Blue1Brown | Khan Academy | Stewart Calculus |
# | **機率統計** | StatQuest | Coursera | $\textit{Introduction to Probability}$ |
# | **整合應用** | - | **MML Book** | **Deep Learning Book** |
